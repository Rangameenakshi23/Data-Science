# %% [markdown]
# # LETS GROW MORE-DATA SCIENCE INTERN\\

# %% [markdown]
# # BEGINNER LEVE TASK

# %% [markdown]
# # Task-3: Image to Pencil Sketch with Python

# %% [markdown]
# Name: Ranga Meenakshi

# %%
import cv2

# %%
image=cv2.imread('dog.jpg')

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1536x580 at 0x7F2B6F3017E0>

# %%
b_and_w_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(b_and_w_image)
# Out:
# <PIL.Image.Image image mode=L size=1536x580 at 0x7F2B6F2B7F40>

# %%
inverted_image = 255 - b_and_w_image

# %%
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=1536x580 at 0x7F2B6F2B7A60>

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %%
inverted_blurred = 255 - blurred

# %%
pencil_sketch = cv2.divide(b_and_w_image, inverted_blurred, scale=256.0)

# %%
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=1536x580 at 0x7F2B6F2B7B50>

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=1536x580 at 0x7F2B9F171CC0>
# <PIL.Image.Image image mode=L size=1536x580 at 0x7F2B6F2B7B80>
